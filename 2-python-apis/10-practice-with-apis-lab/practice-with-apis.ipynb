# %% [markdown]
# <a href="https://colab.research.google.com/github/alextorreswa/DataEngJigsaw/blob/main/2-python-apis/10-practice-with-apis-lab/practice-with-apis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice with APIs

# %% [markdown]
# In the last lesson, we saw how we can gather information about books by using APIs.  In this lesson, we'll you our new found Python skills to use Apple's Itunes API.  That's right, we're going for it.

# %% [markdown]
# ### Some tips before we start

# %% [markdown]
# This may be your first time writing code on your own, and it's understandable if you're feeling a little queasy about the feeling. Here are couple things for you to remember.
#
# 1. Don't try to solve it all at once.  Instead say or write down the first task you need to do, then try to think of the code to do it.
# 2. Once you know what you have to do, if you forget how to code it in Python, [ask Google](https://www.google.com/search?q=how+to+make+a+request+in+python&oq=how+to+make+a+request+in+python&aqs=chrome..69i57j0l5.7493j0j7&sourceid=chrome&ie=UTF-8).
# 3. Try a lot of wrong things.  It's just code. If you break something, it's just digital.  Try to understand to see what went wrong, (and ask Google if you don't understand it) and try again.

# %% [markdown]
# ### Learning more about Prince

# %% [markdown]
# Let's use the Apple API to find out more information about Prince. Because we are asking for information, and not changing say adding a new artist to Itunes, we need to make a GET request with Python to the following URL:
#
# `"https://itunes.apple.com/search?term=prince"`
#
# And to do that we need to use the `requests` module.  Go ahead and write the code to allow us to use the requests module in this document.  Give it a shot in the gray cell below.

# %%
import requests

# %% [markdown]
# > Remember, we need to press `shift` and `enter` simultaneously to execute our code.

# %% [markdown]
# Next, make a `GET` request to the URL we specified above.

# %%
url = "https://itunes.apple.com/search?term=prince"
albums_request = requests.get(url)
print(albums_request.status_code)
# Out:
# 200

# %% [markdown]
# > Remember, we need to press shift and enter simultaneously to execute our code.

# %% [markdown]
# Also, remember that that we'll need to capture the response in a variable.  So, if needed, modify the code above to do so.  Let's call that variable `response`.

# %% [markdown]
# Finally, use that variable to access the JSON.  (Scroll to very bottom, when you are done.)

# %%
album = albums_request.json()
print(album)
# Out:
# {'resultCount': 50, 'results': [{'wrapperType': 'track', 'kind': 'song', 'artistId': 1092903, 'collectionId': 1099846321, 'trackId': 1099846490, 'artistName': 'Deftones', 'collectionName': 'Diamond Eyes (Deluxe Edition)', 'trackName': 'Prince', 'collectionCensoredName': 'Diamond Eyes (Deluxe Edition)', 'trackCensoredName': 'Prince', 'artistViewUrl': 'https://music.apple.com/us/artist/deftones/1092903?uo=4', 'collectionViewUrl': 'https://music.apple.com/us/album/prince/1099846321?i=1099846490&uo=4', 'trackViewUrl': 'https://music.apple.com/us/album/prince/1099846321?i=1099846490&uo=4', 'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/53/c1/73/53c173ee-a5aa-9edd-59e5-7a8c1ee8d8b4/mzaf_10003479721053614198.plus.aac.p.m4a', 'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/cd/bd/cb/cdbdcbfd-0b6e-93ff-61f7-04c9d5da7368/093624919759.jpg/30x30bb.jpg', 'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/cd/bd/cb/cdbdcbfd-0b6e-93ff-61f7-04c9d5da7368/093624919759.jpg/60x60bb.jpg', 'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music124/v4/cd/bd/cb/cdbdcbfd-0b6e-93ff-61f7-04c9d5da7368/093624919759.jpg/100x100bb.jpg', 'collectionPrice': 11.99, 'trackPrice': 1.29, 'releaseDate': '2010-05-04T12:00:00Z', 'collectionExplicitness': 'explicit', 'trackExplicitness': 'notExplicit', 'discCount': 1, 'discNumber': 1, 'trackCount': 14, 'trackNumber': 6, 'trackTimeMillis': 216573, 'country': 'USA', 'currency': 'USD', 'primaryGenreName': 'Hard Rock', 'isStreamable': True}, {'wrapperType': 'track', 'kind': 'feature-movie', 'collectionId': 1171812597, 'trackId': 326568786, 'artistName': 'David Yates', 'collectionName': 'แฮร์รี่ พอตเตอร์ บ็อกเซ็ตฉบับครบเซ็ต', 'trackName': 'Harry Potter and the Half-Blood Prince', 'collectionCensoredName': 'Harry Potter Collection', 'trackCensoredName': 'Harry Potter and the Half-Blood Prince', 'collectionArtistId': 199257486, 'collectionArtistViewUrl': 'https://itunes.apple.com/us/artist/warner-bros-entertainment-inc/199257486?uo=4', 'collectionViewUrl': 'https://itunes.apple.com/us/movie/harry-potter-and-the-half-blood-prince/id326568786?uo=4', 'trackViewUrl': 'https://itunes.apple.com/us/movie/harry-potter-and-the-half-blood-prince/id326568786?uo=4', 'previewUrl': 'https://video-ssl.itunes.apple.com/itunes-assets/Video118/v4/40/2c/ee/402cee22-fbd3-b19d-bec8-7bdd49aa6427/mzvf_6179099479993198931.640x362.h264lc.U.p.m4v', 'artworkUrl30': 'https://is4-ssl.mzstatic.com/image/thumb/Video125/v4/f5/4e/1f/f54e1f4f-52fc-b0dd-4500-f402553bdc42/pr_source.lsr/30x30bb.jpg', 'artworkUrl60': 'https://is4-ssl.mzstatic.com/image/thumb/Video125/v4/f5/4e/1f/f54e1f4f-52fc-b0dd-4500-f402553bdc42/pr_source.lsr/60x60bb.jpg', 'artworkUrl100': 'https://is4-ssl.mzstatic.com/image/thumb/Video125/v4/f5/4e/1f/f54e1f4f-52fc-b0dd-4500-f402553bdc42/pr_source.lsr/100x100bb.jpg', 'collectionPrice': 14.99, 'trackPrice': 14.99, 'trackRentalPrice': 3.99, 'collectionHdPrice': 14.99, 'trackHdPrice': 14.99, 'trackHdRentalPrice': 3.99, 'releaseDate': '2009-07-15T07:00:00Z', 'collectionExplicitness': 'notExplicit', 'trackExplicitness': 'notExplicit', 'discCount': 1, 'discNumber': 1, 'trackCount': 8, 'trackNumber': 6, 'trackTimeMillis': 9214745, 'country': 'USA', 'currency': 'USD', 'primaryGenreName': 'Kids & Family', 'contentAdvisoryRating': 'PG', 'longDescription': "Emboldened by the return of Lord Voldemort, the Death Eaters are wreaking havoc in both the Muggle and wizarding worlds and Hogwarts is no longer the safe haven it once was. Dumbledore is intent upon preparing Harry for the final battle that he knows is fast approaching. He needs Harry to help him uncover a vital key to unlocking Voldemort's defenses--critical information known only to Hogwarts' former Potions Professor, Horace Slughorn. Meanwhile, teenage hormones rage across the ramparts as Harry's long friendship with Ginny Weasley is growing into something deeper. But standing in the way is Ginny's boyfriend, Dea ...

# %% [markdown]
# ### Summary
#
# Great job - this was not such a simple introduction to code.  If you were able to do this successfully.  *Take a break, and then **try to perform these steps again, this time without any guidance**.*
#
# The goal when coding, isn't to try to memorize anything.  There's way too much room for mistakes if we aren't constantly trying to make sense of what we are writing.  So instead, write out (or explain) to yourself what you need to do first, and then write out the corresponding code.  Then explain to yourself what you need to do second.
#
# Then, **as a bonus**, take a look at [the documentation](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/#searchexamples) that Apple provides on the API, and try some of the examples provided there, using the same pattern that we went through above.
